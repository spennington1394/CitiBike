# %%
import pandas as pd
import glob

# %%
path = ("Resources/") 
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df_combined= pd.concat(li, axis=0, ignore_index=True)

# %%
df_combined
# Out:
#           tripduration                 starttime                  stoptime  \
# 0                 1062  2020-06-01 00:00:03.3720  2020-06-01 00:17:46.2080
# 1                 3810  2020-06-01 00:00:03.5530  2020-06-01 01:03:33.9360
# 2                 1017  2020-06-01 00:00:09.6140  2020-06-01 00:17:06.8330
# 3                  226  2020-06-01 00:00:12.1780  2020-06-01 00:03:58.8640
# 4                 1437  2020-06-01 00:00:21.2550  2020-06-01 00:24:18.9650
# ...                ...                       ...                       ...
# 19506852          1587  2020-01-31 23:59:26.8820  2020-02-01 00:25:54.4890
# 19506853           222  2020-01-31 23:59:32.6410  2020-02-01 00:03:15.4720
# 19506854           163  2020-01-31 23:59:39.1780  2020-02-01 00:02:23.0400
# 19506855           327  2020-01-31 23:59:49.2310  2020-02-01 00:05:16.3790
# 19506856           484  2020-01-31 23:59:57.0360  2020-02-01 00:08:01.1820
#
#           start station id          start station name  \
# ...

# %%
df_combined['Year'] = df_combined["stoptime"].str[:4]
df_combined['Month'] = df_combined['stoptime'].str[5:7]
df_combined['Date'] = df_combined["stoptime"].str[:10]
df_combined['Time_Hr'] = df_combined["stoptime"].str[11:13]
df_combined.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1062  2020-06-01 00:00:03.3720  2020-06-01 00:17:46.2080
# 1          3810  2020-06-01 00:00:03.5530  2020-06-01 01:03:33.9360
# 2          1017  2020-06-01 00:00:09.6140  2020-06-01 00:17:06.8330
# 3           226  2020-06-01 00:00:12.1780  2020-06-01 00:03:58.8640
# 4          1437  2020-06-01 00:00:21.2550  2020-06-01 00:24:18.9650
#
#    start station id        start station name  start station latitude  \
# 0              3419       Douglass St & 4 Ave               40.679279
# 1               366  Clinton Ave & Myrtle Ave               40.693261
# 2               389       Broadway & Berry St               40.710446
# 3              3255           8 Ave & W 31 St               40.750585
# 4               367   E 53 St & Lexington Ave               40.758281
#
#    start station longitude  end station id             end station name  \
# ...

# %%
df_combined.to_csv("Tableau/data_merged.csv", index=False)
